# %% [markdown]
# # FALTA AJUSTAR ALGUMAS ONDAS. FAZER ISSO BUSCANDO O MELHOR AJUSTE POSSÍVEL. AINDA NÃO SABEMOS SE HÁ DUAS INTERFACES OU APENAS UMA. ANALISAR ISSO PELOS PLOTS. BASTA MUDAR OS LIMITES DAS LINHAS EM DOST_MIN E DIST_MAX.

# %%
import numpy as np
import matplotlib.pyplot as plt

# ==============================================================================
# PAINEL DE CONTROLE (Configure quantos tiros quiser)
# ==============================================================================

# Defina os arquivos de pick, cores, e agora os SEGMENTOS para o ajuste das retas.
# ATENÇÃO: Você precisa ajustar os valores de 'dist_min' e 'dist_max' para cada segmento.
analises = {
    'n1': {
        'arquivo': 'picks/n1m2',
        'cor_dados': 'deepskyblue',
        'segmentos': {
            'Refratada': {'dist_min': 0, 'dist_max': 99999, 'cor': 'deepskyblue'},
            'Reta 2': {'dist_min': 0, 'dist_max': 0, 'cor': 'darkblue'},
        }
    },
    'n4': {
        'arquivo': 'picks/n4',
        'cor_dados': 'darkblue',
        'segmentos': {
            'Direta': {'dist_min': 83, 'dist_max': 9999, 'cor': 'darkblue'},
            'Refratada': {'dist_min': 0, 'dist_max': 83, 'cor': 'darkblue'},
        }
    },
    'n6direita': {
        'arquivo': 'picks/n6direita',
        'cor_dados': 'darkgreen',
        'segmentos': {
            'Refratada': {'dist_min': 0, 'dist_max': 40, 'cor': 'darkgreen'},
            'Refratada': {'dist_min': 40, 'dist_max': 999, 'cor': 'lime'},
        }
    },
    'n6esquerda': {
        'arquivo': 'picks/n6esquerda',
        'cor_dados': 'lime',
        'segmentos': {
            'Refratada': {'dist_min': 0, 'dist_max': 45, 'cor': 'green'},
            'Reta 2': {'dist_min': 45, 'dist_max': 999, 'cor': 'darkgreen'},
        }
    },
    'n13': {
        'arquivo': 'picks/n13',
        'cor_dados': 'darkred',
        'segmentos': {
            'Direta': {'dist_min': 0, 'dist_max': 20, 'cor': 'darkred'},
            'Refratada': {'dist_min': 19, 'dist_max': 99999, 'cor': 'darkred'},
        }
    },
    'n12': {
        'arquivo': 'picks/n12n2',
        'cor_dados': 'indianred',
        'segmentos': {
             'Refratada': {'dist_min': 0, 'dist_max': 99999, 'cor': 'indianred'},
             'Reta 2': {'dist_min': 0, 'dist_max': 0, 'cor': 'firebrick'},
        }
    },
    'n2': {
        'arquivo': 'picks/n2n2',
        'cor_dados': 'blue',
        'segmentos': {
            'Refratada': {'dist_min': 0, 'dist_max': 999999, 'cor': 'blue'},
            'Reta 2': {'dist_min': 0, 'dist_max': 0, 'cor': 'darkblue'},
        }
    },
    'n10': {
        'arquivo': 'picks/n10n',
        'cor_dados': 'firebrick',
        'segmentos': {
            'Refratada': {'dist_min': 0, 'dist_max': 999999, 'cor': 'firebrick'},
            'Reta 2': {'dist_min': 0, 'dist_max': 0, 'cor': 'firebrick'},
        }
    },
}

# ==============================================================================
# --- ETAPA 1: Processamento de Todos os Dados ---

print("--- Iniciando Processamento de Dados ---")
dados_processados = {}

for nome_tiro, config in analises.items():
    nome_arquivo = config['arquivo']
    print(f"\n--- Processando o '{nome_tiro}': {nome_arquivo} ---")
    
    try:
        tempos, posicoes = np.loadtxt(nome_arquivo, unpack=True)
    except Exception as e:
        print(f"ERRO ao carregar o arquivo '{nome_arquivo}': {e}")
        continue

    dados_processados[nome_tiro] = {
        'posicoes': posicoes,
        'tempos': tempos,
        'cor_dados': config['cor_dados'],
        'ajustes': []
    }

    if 'segmentos' in config:
        for nome_segmento, limites in config['segmentos'].items():
            mascara = (posicoes >= limites['dist_min']) & (posicoes <= limites['dist_max'])
            pos_segmento = posicoes[mascara]
            t_segmento = tempos[mascara]
            
            if len(pos_segmento) < 2:
                continue
            
            inclinacao, intercepto = np.polyfit(pos_segmento, t_segmento, 1)
            velocidade = abs(1 / inclinacao)
            
            dados_processados[nome_tiro]['ajustes'].append({
                'x': pos_segmento,
                'y': inclinacao * pos_segmento + intercepto,
                'cor': limites['cor'],
                'nome_segmento': nome_segmento,
                'velocidade': velocidade,
            })
            print(f"  -> Segmento '{nome_segmento}' calculado com velocidade {velocidade:.0f} m/s")

# ==============================================================================
# --- ETAPA 2: GERAÇÃO DA FIGURA 1 (APENAS PONTOS) ---
# (Esta parte não foi alterada)
print("\n--- Gerando Figura 1: Apenas os Pontos de Pick ---")
fig1, ax1 = plt.subplots(figsize=(12, 8))
for nome_tiro, dados in dados_processados.items():
    ax1.scatter(dados['posicoes'], dados['tempos'], label=nome_tiro, color=dados['cor_dados'], alpha=0.8, s=50)
ax1.set_xlabel('Posição do Receptor (m)')
ax1.set_ylabel('Tempo (s)')
ax1.set_title('Análise Comparativa de Picks (Pontos)')
ax1.grid(True)
ax1.invert_yaxis()
ax1.legend(loc='upper left', bbox_to_anchor=(1.02, 1), title="Tiros")
plt.tight_layout(rect=[0, 0, 0.85, 1])
nome_figura1 = 'analise_comparativa_picks.png'
plt.savefig(nome_figura1, dpi=300, bbox_inches='tight')
print(f"Gráfico de pontos salvo como: {nome_figura1}")
plt.show()


# ==============================================================================
# --- ETAPA 3: GERAÇÃO DA FIGURA 2 (RETAS COM LEGENDA CUSTOMIZADA E CORES) ---

print("\n--- Gerando Figura 2: Apenas as Retas de Ajuste ---")
fig2, ax2 = plt.subplots(figsize=(12, 8))

# Posição inicial Y para o texto da legenda (1.0 = topo do gráfico)
legend_y_pos = 1.0
# Espaçamento vertical entre as linhas da legenda
line_height = 0.05

for nome_tiro, dados in dados_processados.items():
    # Desenha as retas no gráfico
    for ajuste in dados['ajustes']:
        ax2.plot(ajuste['x'], ajuste['y'], '-', color=ajuste['cor'], lw=2.5)

    # --- Construção da legenda customizada, linha por linha ---
    
    # Adiciona o título do tiro na legenda
    ax2.text(1.02, legend_y_pos, f"--- {nome_tiro} ---", transform=ax2.transAxes, fontsize=10, weight='bold', verticalalignment='top')
    legend_y_pos -= line_height # Move a posição Y para a próxima linha

    # Adiciona as linhas de resultado de cada reta
    for ajuste in dados['ajustes']:
        # Adiciona o texto da reta, com a cor correspondente
        legenda_texto = f"■ {ajuste['nome_segmento']}: {ajuste['velocidade']:.0f} m/s"
        ax2.text(1.02, legend_y_pos, legenda_texto,
                 transform=ax2.transAxes,
                 fontsize=10,
                 color=ajuste['cor'], # <--- AQUI A MÁGICA ACONTECE
                 verticalalignment='top')
        legend_y_pos -= line_height

    # Adiciona um separador
    ax2.text(1.02, legend_y_pos, "-" * 25, transform=ax2.transAxes, fontsize=10, verticalalignment='top')
    legend_y_pos -= line_height


ax2.set_xlabel('Posição do Receptor (m)')
ax2.set_ylabel('Tempo (s)')
ax2.set_title('Análise Comparativa (Retas de Ajuste)')
ax2.grid(True)
ax2.invert_yaxis()

# Ajusta o layout para garantir que a legenda não seja cortada
plt.tight_layout(rect=[0, 0, 0.80, 1])

nome_figura2 = 'analise_retas_ajustadas.png'
plt.savefig(nome_figura2, dpi=300, bbox_inches='tight')
print(f"Gráfico de retas salvo como: {nome_figura2}")
plt.show()
# Out:
# --- Iniciando Processamento de Dados ---
#
# --- Processando o 'n1': picks/n1m2 ---
#   -> Segmento 'Refratada' calculado com velocidade 2208 m/s
#
# --- Processando o 'n4': picks/n4 ---
#   -> Segmento 'Direta' calculado com velocidade 472 m/s
#   -> Segmento 'Refratada' calculado com velocidade 1492 m/s
#
# --- Processando o 'n6direita': picks/n6direita ---
#   -> Segmento 'Refratada' calculado com velocidade 1633 m/s
#
# --- Processando o 'n6esquerda': picks/n6esquerda ---
#   -> Segmento 'Refratada' calculado com velocidade 1055 m/s
#
# --- Processando o 'n13': picks/n13 ---
#   -> Segmento 'Direta' calculado com velocidade 530 m/s
#   -> Segmento 'Refratada' calculado com velocidade 1480 m/s
#
# --- Processando o 'n12': picks/n12n2 ---
#   -> Segmento 'Refratada' calculado com velocidade 2100 m/s
#
# --- Processando o 'n2': picks/n2n2 ---
#   -> Segmento 'Refratada' calculado com velocidade 1636 m/s
#
# --- Processando o 'n10': picks/n10n ---
#   -> Segmento 'Refratada' calculado com velocidade 2064 m/s
#
# --- Gerando Figura 1: Apenas os Pontos de Pick ---
# Gráfico de pontos salvo como: analise_comparativa_picks.png
# --- Gerando Figura 2: Apenas as Retas de Ajuste ---
# Gráfico de retas salvo como: analise_retas_ajustadas.png

# %%
import numpy as np
import matplotlib.pyplot as plt

# ==============================================================================
# PAINEL DE CONTROLE (Configure quantos tiros quiser)
# ==============================================================================

# Defina os arquivos de pick, cores, e agora os SEGMENTOS para o ajuste das retas.
# ATENÇÃO: Você precisa ajustar os valores de 'dist_min' e 'dist_max' para cada segmento.
analises = {
    'n1': {
        'arquivo': 'picks/n1m2',
        'cor_dados': 'deepskyblue',
        'segmentos': {
            'Reta 1': {'dist_min': 0, 'dist_max': 99999, 'cor': 'deepskyblue'},
            'Reta 2': {'dist_min': 0, 'dist_max': 0, 'cor': 'darkblue'},
        }
    },
    'n4': {
        'arquivo': 'picks/n4',
        'cor_dados': 'darkblue',
        'segmentos': {
            'Direta': {'dist_min': 83, 'dist_max': 9999, 'cor': 'darkblue'},
            'Refratada': {'dist_min': 0, 'dist_max': 83, 'cor': 'darkblue'},
        }
    },
    'n6direita': {
        'arquivo': 'picks/n6direita',
        'cor_dados': 'darkgreen',
        'segmentos': {
            'Reta 1': {'dist_min': 0, 'dist_max': 40, 'cor': 'darkgreen'},
            'Reta 2': {'dist_min': 40, 'dist_max': 999, 'cor': 'lime'},
        }
    },
    'n6esquerda': {
        'arquivo': 'picks/n6esquerda',
        'cor_dados': 'lime',
        'segmentos': {
            'Reta 1': {'dist_min': 0, 'dist_max': 45, 'cor': 'green'},
            'Reta 2': {'dist_min': 45, 'dist_max': 999, 'cor': 'darkgreen'},
        }
    },
    'n13': {
        'arquivo': 'picks/n13',
        'cor_dados': 'darkred',
        'segmentos': {
            'Direta': {'dist_min': 0, 'dist_max': 20, 'cor': 'darkred'},
            'Refratada': {'dist_min': 19, 'dist_max': 99999, 'cor': 'darkred'},
        }
    },
    'n12': {
        'arquivo': 'picks/n12n2',
        'cor_dados': 'indianred',
        'segmentos': {
             'Reta 1': {'dist_min': 0, 'dist_max': 99999, 'cor': 'indianred'},
             'Reta 2': {'dist_min': 0, 'dist_max': 0, 'cor': 'firebrick'},
        }
    },
    'n2': {
        'arquivo': 'picks/n2n2',
        'cor_dados': 'blue',
        'segmentos': {
            'Reta 1': {'dist_min': 0, 'dist_max': 999999, 'cor': 'blue'},
            'Reta 2': {'dist_min': 0, 'dist_max': 0, 'cor': 'darkblue'},
        }
    },
    'n10': {
        'arquivo': 'picks/n10n',
        'cor_dados': 'firebrick',
        'segmentos': {
            'Reta 1': {'dist_min': 0, 'dist_max': 999999, 'cor': 'firebrick'},
            'Reta 2': {'dist_min': 0, 'dist_max': 0, 'cor': 'firebrick'},
        }
    },
}

print("--- Iniciando Processamento de Dados ---")
dados_processados = {}

for nome_tiro, config in analises.items():
    nome_arquivo = config['arquivo']
    print(f"\n--- Processando o '{nome_tiro}': {nome_arquivo} ---")
    
    try:
        tempos, posicoes = np.loadtxt(nome_arquivo, unpack=True)
    except Exception as e:
        print(f"ERRO ao carregar o arquivo '{nome_arquivo}': {e}")
        continue

    # Armazena os pontos brutos
    dados_processados[nome_tiro] = {
        'posicoes': posicoes,
        'tempos': tempos,
        'cor_dados': config['cor_dados'],
        'ajustes': [] # Lista para guardar as informações das retas
    }

    # Calcula os ajustes de reta
    if 'segmentos' in config:
        for nome_segmento, limites in config['segmentos'].items():
            mascara = (posicoes >= limites['dist_min']) & (posicoes <= limites['dist_max'])
            pos_segmento = posicoes[mascara]
            t_segmento = tempos[mascara]
            
            if len(pos_segmento) < 2:
                continue
            
            inclinacao, intercepto = np.polyfit(pos_segmento, t_segmento, 1)
            velocidade = abs(1 / inclinacao)
            
            # Armazena os dados da reta ajustada
            dados_processados[nome_tiro]['ajustes'].append({
                'x': pos_segmento,
                'y': inclinacao * pos_segmento + intercepto,
                'cor': limites['cor'],
                'label': f'{nome_tiro} - {nome_segmento} ({velocidade:.0f} m/s)'
            })
            print(f"  -> Segmento '{nome_segmento}' calculado com velocidade {velocidade:.0f} m/s")

# ==============================================================================
# --- ETAPA 2: GERAÇÃO DA FIGURA 1 (APENAS PONTOS) ---

print("\n--- Gerando Figura 1: Apenas os Pontos de Pick ---")
fig1, ax1 = plt.subplots(figsize=(12, 8))

for nome_tiro, dados in dados_processados.items():
    ax1.scatter(dados['posicoes'], dados['tempos'], label=nome_tiro, color=dados['cor_dados'], alpha=0.8, s=50)

ax1.set_xlabel('Posição do Receptor (m)')
ax1.set_ylabel('Tempo (s)')
ax1.set_title('Análise Comparativa de Picks (Pontos)')
ax1.grid(True)
ax1.invert_yaxis()
ax1.legend(loc='upper left', bbox_to_anchor=(1.02, 1), title="Tiros")
plt.tight_layout(rect=[0, 0, 0.85, 1])

nome_figura1 = 'analise_comparativa_picks.png'
plt.savefig(nome_figura1, dpi=300, bbox_inches='tight')
print(f"Gráfico de pontos salvo como: {nome_figura1}")
plt.show()


# ==============================================================================
# --- ETAPA 3: GERAÇÃO DA FIGURA 2 (APENAS RETAS DE AJUSTE) ---

print("\n--- Gerando Figura 2: Apenas as Retas de Ajuste ---")
fig2, ax2 = plt.subplots(figsize=(12, 8))

for nome_tiro, dados in dados_processados.items():
    for ajuste in dados['ajustes']:
        ax2.plot(ajuste['x'], ajuste['y'], '-', color=ajuste['cor'], lw=2.5, label=ajuste['label'])

ax2.set_xlabel('Posição do Receptor (m)')
ax2.set_ylabel('Tempo (s)')
ax2.set_title('Análise Comparativa (Retas de Ajuste)')
ax2.grid(True)
ax2.invert_yaxis()
ax2.legend(loc='upper left', bbox_to_anchor=(1.02, 1), title="Ajustes")
plt.tight_layout(rect=[0, 0, 0.80, 1])

nome_figura2 = 'analise_retas_ajustadas.png'
plt.savefig(nome_figura2, dpi=300, bbox_inches='tight')
print(f"Gráfico de retas salvo como: {nome_figura2}")
plt.show()
# Out:
# --- Iniciando Processamento de Dados ---
#
# --- Processando o 'n1': picks/n1m2 ---
#   -> Segmento 'Reta 1' calculado com velocidade 2208 m/s
#
# --- Processando o 'n4': picks/n4 ---
#   -> Segmento 'Direta' calculado com velocidade 472 m/s
#   -> Segmento 'Refratada' calculado com velocidade 1492 m/s
#
# --- Processando o 'n6direita': picks/n6direita ---
#   -> Segmento 'Reta 2' calculado com velocidade 1633 m/s
#
# --- Processando o 'n6esquerda': picks/n6esquerda ---
#   -> Segmento 'Reta 1' calculado com velocidade 1055 m/s
#
# --- Processando o 'n13': picks/n13 ---
#   -> Segmento 'Direta' calculado com velocidade 530 m/s
#   -> Segmento 'Refratada' calculado com velocidade 1480 m/s
#
# --- Processando o 'n12': picks/n12n2 ---
#   -> Segmento 'Reta 1' calculado com velocidade 2100 m/s
#
# --- Processando o 'n2': picks/n2n2 ---
#   -> Segmento 'Reta 1' calculado com velocidade 1636 m/s
#
# --- Processando o 'n10': picks/n10n ---
#   -> Segmento 'Reta 1' calculado com velocidade 2064 m/s
#
# --- Gerando Figura 1: Apenas os Pontos de Pick ---
# Gráfico de pontos salvo como: analise_comparativa_picks.png
# --- Gerando Figura 2: Apenas as Retas de Ajuste ---
# Gráfico de retas salvo como: analise_retas_ajustadas.png

# %% [raw]
# --------------------
#
#
# COMPARANDO DOIS DADOS
#
# --------------------

# %%
import numpy as np
import matplotlib.pyplot as plt

# ==============================================================================
# PAINEL DE CONTROLE (Configure sua análise aqui)
# ==============================================================================

# 1. Defina os parâmetros para o TIRO DIRETO
arquivo_direto = 'picks/n13'
segmentos_direto = {
    "Onda Direta": { "dist_min": 0, "dist_max": 19, "cor": "red" },
    "Refratada 1": { "dist_min": 21, "dist_max": 65, "cor": "darkred" },
    "Refratada 2": { "dist_min": 0, "dist_max": 0, "cor": "purple" }
}

# 2. Defina os parâmetros para o TIRO REVERSO
arquivo_reverso = 'picks/n4'
segmentos_reverso = {
    "Onda Direta": { "dist_min": 86, "dist_max": 99999, "cor": "blue" },
    "Refratada 1": { "dist_min": 0, "dist_max": 83, "cor": "darkblue" },
    "Refratada 2": { "dist_min": 0, "dist_max": 0, "cor": "mediumorchid" }
}

# 3. Informe a distância total entre os dois pontos de tiro (em metros)
distancia_total_AB = 100.0

# ==============================================================================

# --- FUNÇÃO que apenas PROCESSA os dados, sem plotar ---
def processar_tiro(nome_do_arquivo, segmentos_para_analise):
    print(f"\n--- Processando o arquivo: {nome_do_arquivo} ---")
    try:
        tempos_brutos, posicoes_brutas = np.loadtxt(nome_do_arquivo, unpack=True)
    except Exception as e:
        print(f"ERRO ao carregar o arquivo: {e}")
        return None

    indices_sorted = np.argsort(posicoes_brutas)
    posicoes = posicoes_brutas[indices_sorted]
    tempos = tempos_brutos[indices_sorted]
    print(f"Arquivo carregado com {len(posicoes)} pontos.")
    
    resultados = {
        'posicoes': posicoes,
        'tempos': tempos,
        'velocidades': {},
        'interceptos': {},
        'ajustes': {}
    }
    
    for nome, limites in segmentos_para_analise.items():
        mascara = (posicoes >= limites['dist_min']) & (posicoes <= limites['dist_max'])
        pos_segmento, t_segmento = posicoes[mascara], tempos[mascara]
        
        if len(pos_segmento) < 2:
            print(f"AVISO: Segmento '{nome}' tem pontos insuficientes.")
            continue
            
        inclinacao, intercepto = np.polyfit(pos_segmento, t_segmento, 1)
        velocidade = abs(1 / inclinacao)
        
        resultados['velocidades'][nome] = velocidade
        resultados['interceptos'][nome] = intercepto
        resultados['ajustes'][nome] = {
            'x': pos_segmento,
            'y': inclinacao * pos_segmento + intercepto,
            'cor': limites['cor'],
            'label': f'Ajuste {nome} ({velocidade:.0f} m/s)'
        }
        print(f"  -> Segmento '{nome}': Velocidade = {velocidade:.2f} m/s")
        
    return resultados

# --- ANÁLISE DOS DADOS ---
dados_direto = processar_tiro(arquivo_direto, segmentos_direto)
dados_reverso = processar_tiro(arquivo_reverso, segmentos_reverso)

# --- GERAÇÃO DA FIGURA 1: DROMOCRONAS COMBINADAS ---
if dados_direto and dados_reverso:
    print("\n--- Gerando gráfico combinado das dromocronas ---")
    fig1, ax1 = plt.subplots(figsize=(14, 8))

    # Plota dados do tiro direto
    # <--- MUDANÇA AQUI: Cor dos pontos alterada para 'black' ---
    ax1.scatter(dados_direto['posicoes'], dados_direto['tempos'], label=f'Dados Direto ({arquivo_direto})', marker='o', c='black')
    for nome, ajuste in dados_direto['ajustes'].items():
        ax1.plot(ajuste['x'], ajuste['y'], '-', color=ajuste['cor'], lw=2.5, label=f'Direto - {ajuste["label"]}')

    # Plota dados do tiro reverso
    # <--- MUDANÇA AQUI: Cor dos pontos alterada para 'black' ---
    ax1.scatter(dados_reverso['posicoes'], dados_reverso['tempos'], label=f'Dados Reverso ({arquivo_reverso})', marker='x', c='black')
    for nome, ajuste in dados_reverso['ajustes'].items():
        ax1.plot(ajuste['x'], ajuste['y'], '--', color=ajuste['cor'], lw=2.5, label=f'Reverso - {ajuste["label"]}')

    # Configuração do gráfico combinado
    ax1.set_xlabel('Posição do Receptor (m)')
    ax1.set_ylabel('Tempo (s)')
    ax1.set_title('Análise Combinada das Dromocronas (Tiro Direto e Reverso)')
    ax1.legend()
    ax1.grid(True)
    ax1.invert_yaxis()
    plt.savefig('dromocronas_combinadas.png', dpi=300, bbox_inches='tight')
    plt.show()

# --- MODELO GEOLÓGICO (JUNÇÃO DOS RESULTADOS) ---
if dados_direto and dados_reverso:
    # ... (O restante do seu código de cálculo e a segunda figura não precisam de alterações) ...
    print("\n--- Unificando resultados para gerar os Modelos Geológicos ---")
    pos_direto, t_direto, vel_direto, int_direto = dados_direto['posicoes'], dados_direto['tempos'], dados_direto['velocidades'], dados_direto['interceptos']
    pos_reverso, t_reverso, vel_reverso, int_reverso = dados_reverso['posicoes'], dados_reverso['tempos'], dados_reverso['velocidades'], dados_reverso['interceptos']
    v1_direta = vel_direto.get("Onda Direta", 0)
    v1_reversa = vel_reverso.get("Onda Direta", 0)
    v1 = (v1_direta + v1_reversa) / 2
    if v1 == 0:
        print("AVISO: Não foi possível calcular V1. Verifique os segmentos 'Onda Direta'.")
    else:
        print(f"\n==> Velocidade V1 Média utilizada: {v1:.2f} m/s")
    vd1 = vel_direto.get("Refratada 1", 0)
    vu1 = vel_reverso.get("Refratada 1", 0)
    tid1 = int_direto.get("Refratada 1", 0)
    mascara_refratada_rev1 = (pos_reverso >= segmentos_reverso['Refratada 1']['dist_min']) & (pos_reverso <= segmentos_reverso['Refratada 1']['dist_max'])
    pos_refratada_rev1 = pos_reverso[mascara_refratada_rev1]
    t_refratada_rev1 = t_reverso[mascara_refratada_rev1]
    tiu1 = 0
    if len(pos_refratada_rev1) >= 2:
        _, tiu1 = np.polyfit(distancia_total_AB - pos_refratada_rev1, t_refratada_rev1, 1)
    tempo_reciproco_AB = np.interp(distancia_total_AB, pos_direto, t_direto)
    print(f"Tempo Recíproco (t_AB) estimado: {tempo_reciproco_AB:.4f} s")
    if "Refratada 2" in vel_direto and "Refratada 2" in vel_reverso:
        is_3_layers = True
        vd2 = vel_direto.get("Refratada 2", 0)
        vu2 = vel_reverso.get("Refratada 2", 0)
    else:
        is_3_layers = False
    print("\n--- Resultados da 1ª Interface ---")
    if v1 > 0 and vd1 > 0 and vu1 > 0:
        ic1_rad = 0.5 * (np.arcsin(v1/vd1) + np.arcsin(v1/vu1))
        gama1_rad = 0.5 * (np.arcsin(v1/vd1) - np.arcsin(v1/vu1))
        v2_intersecao = v1 / np.sin(ic1_rad)
        h_A1_perp = (tid1 * v1 * np.cos(ic1_rad)) / 2
        h_B1_perp = (tiu1 * v1 * np.cos(ic1_rad)) / 2
        Z_A1 = h_A1_perp / np.cos(gama1_rad)
        Z_B1 = h_B1_perp / np.cos(gama1_rad)
        t_reverso_interp = np.interp(pos_direto, pos_reverso, t_reverso)
        t_v_menos1 = 0.5 * (t_direto - t_reverso_interp + tempo_reciproco_AB)
        incl_v2_real, _ = np.polyfit(pos_direto, t_v_menos1, 1)
        v2_real = 1 / incl_v2_real
        delay_time1 = 0.5 * (t_direto + t_reverso_interp - tempo_reciproco_AB)
        ic1_real_rad = np.arcsin(v1 / v2_real)
        h1x_perp = (delay_time1 * v1) / np.cos(ic1_real_rad)
        Z1x_vertical = h1x_perp / np.cos(gama1_rad)
        print("\n--- Gerando gráfico do modelo geológico ---")
        plt.figure(figsize=(14, 8))
        ax2 = plt.gca()
        ax2.plot(pos_direto, -Z1x_vertical, 'o-', label='Interface 1 (M. Recíproco)', color='saddlebrown', mfc='tan', lw=2.5, zorder=10)
        ax2.plot([0, distancia_total_AB], [-Z_A1, -Z_B1], '--', color='darkviolet', lw=2, label='Interface 1 (M. Interseção)')
        texto_reciproco = (f"Modelo (M. Recíproco):\n----------------------------------\nV1 (média): {v1:.0f} m/s\nV2 (Real): {v2_real:.0f} m/s\nic₁ (Real): {np.degrees(ic1_real_rad):.1f}°\nProf. Mín 1: {np.min(Z1x_vertical):.1f} m\nProf. Máx 1: {np.max(Z1x_vertical):.1f} m")
        texto_intersecao = (f"Modelo (M. Interseção):\n----------------------------------\nV2 (Estimada): {v2_intersecao:.0f} m/s\nic₁ (médio): {np.degrees(ic1_rad):.1f}°\nγ₁ (médio): {np.degrees(gama1_rad):.1f}°\nProf. em A (Zₐ₁): {Z_A1:.1f} m\nProf. em B (Zᵦ₁): {Z_B1:.1f} m")
        if is_3_layers and v2_real > 0 and vd2 > 0 and vu2 > 0:
            print("\n--- Resultados da 2ª Interface ---")
            ic2_rad = 0.5 * (np.arcsin(v2_real/vd2) + np.arcsin(v2_real/vu2))
            gama2_rad = 0.5 * (np.arcsin(v2_real/vd2) - np.arcsin(v2_real/vu2))
            v3_intersecao = v2_real / np.sin(ic2_rad)
            ti_d2 = int_direto.get("Refratada 2", 0)
            i13_rad = np.arcsin(v1/v3_intersecao)
            termo_h1 = (2 * Z_A1 * np.cos(i13_rad)) / v1
            h2_espessura = ( (ti_d2 - termo_h1) * v2_real ) / (2 * np.cos(ic2_rad))
            Z_A2 = Z_A1 + h2_espessura
            Z_B2 = Z_B1 + h2_espessura
            ax2.plot([0, distancia_total_AB], [-Z_A2, -Z_B2], '--', color='crimson', lw=2.5, label='Interface 2 (M. Interseção)')
            texto_reciproco += f"\nV3 (Estimada): {v3_intersecao:.0f} m/s"
            texto_intersecao += (f"\n\nInterface 2:\n----------------------------------\nV3 (Estimada): {v3_intersecao:.0f} m/s\nic₂ (médio): {np.degrees(ic2_rad):.1f}°\nγ₂ (médio): {np.degrees(gama2_rad):.1f}°\nEspessura h₂: {h2_espessura:.1f} m")
        ax2.set_title('Figura Final: Comparação dos Modelos Geológicos')
        ax2.text(0.90, 0.99, texto_reciproco, transform=ax2.transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='skyblue', alpha=0.7))
        ax2.text(0.07, 0.99, texto_intersecao, transform=ax2.transAxes, fontsize=10, verticalalignment='top', horizontalalignment='right', bbox=dict(boxstyle='round,pad=0.5', fc='wheat', alpha=0.7))
        ax2.set_xlabel('Posição (m)')
        ax2.set_ylabel('Profundidade (m)')
        ax2.legend(loc='lower left')
        ax2.grid(True)
        ax2.axis('equal')
        plt.savefig('interfaces_finais_comparativo.png', dpi=300, bbox_inches='tight')
        plt.show()
    else:
        print("\nCálculo do modelo geológico não pôde ser concluído devido a velocidades inválidas (V1, Vd1 ou Vu1 são zero).")
else:
    print("\nAnálise não pôde ser concluída pois um ou ambos os arquivos de tiro tiveram erro.")
# Out:
# --- Processando o arquivo: picks/n13 ---
# Arquivo carregado com 100 pontos.
#   -> Segmento 'Onda Direta': Velocidade = 533.01 m/s
#   -> Segmento 'Refratada 1': Velocidade = 1587.54 m/s
# AVISO: Segmento 'Refratada 2' tem pontos insuficientes.
#
# --- Processando o arquivo: picks/n4 ---
# Arquivo carregado com 96 pontos.
#   -> Segmento 'Onda Direta': Velocidade = 371.01 m/s
#   -> Segmento 'Refratada 1': Velocidade = 1491.66 m/s
# AVISO: Segmento 'Refratada 2' tem pontos insuficientes.
#
# --- Gerando gráfico combinado das dromocronas ---
# --- Unificando resultados para gerar os Modelos Geológicos ---
#
# ==> Velocidade V1 Média utilizada: 452.01 m/s
# Tempo Recíproco (t_AB) estimado: 0.0940 s
#
# --- Resultados da 1ª Interface ---
#
# --- Gerando gráfico do modelo geológico ---

# %% [raw]
# --------------------
#
#
# Plotando dois arquivos num mesmo gráfico
#
#
# --------------------

# %%
import numpy as np
import matplotlib.pyplot as plt

# ==============================================================================
# PAINEL DE CONTROLE (Configure os dois tiros que você quer comparar)
# ==============================================================================

# Defina aqui os parâmetros para cada um dos dois tiros que serão analisados
analises = {
    'n12': {
        'arquivo': 'picks/nu=12.txt',  # <--- Nome do primeiro arquivo
        'cor_dados': 'blue',
        'segmentos': {
            'Onda Direta': {'dist_min': 86, 'dist_max': 99999, 'cor': 'darkblue'},
            'Refratada 1': {'dist_min': 74, 'dist_max': 86, 'cor': 'blue'},
            'Refratada 2': {'dist_min': 10, 'dist_max': 74, 'cor': 'lightblue'}
        }
    },
    
    'n13': {
        'arquivo': 'picks/n13',  # <--- Nome do segundo arquivo
        'cor_dados': 'red',
        'segmentos': {
            'Onda Direta': {'dist_min': 0, 'dist_max': 0, 'cor': 'darkred'},
            'Refratada 1': {'dist_min': 21, 'dist_max': 65, 'cor': 'red'},
            'Refratada 2': {'dist_min': 80, 'dist_max': 99999, 'cor': 'lightsalmon'}
        },
    
        
    }
}

# ==============================================================================


# --- Início da Análise e Plotagem ---
plt.figure(figsize=(14, 8))
ax = plt.gca()
print("--- Iniciando Análise Comparativa de Tiros ---")

# Loop principal para analisar cada tiro definido no painel de controle
for nome_tiro, config in analises.items():
    nome_arquivo = config['arquivo']
    segmentos_para_analise = config['segmentos']
    cor_dados = config['cor_dados']
    
    print(f"\n--- Analisando o '{nome_tiro}': {nome_arquivo} ---")
    
    # --- 1. Carregar e Limpar os Dados ---
    try:
        tempos_brutos, posicoes_brutas = np.loadtxt(nome_arquivo, unpack=True)
    except Exception as e:
        print(f"ERRO ao carregar o arquivo '{nome_arquivo}': {e}")
        continue # Pula para o próximo tiro

    indices_sorted = np.argsort(posicoes_brutas)
    posicoes = posicoes_brutas[indices_sorted]
    tempos = tempos_brutos[indices_sorted]
    
    # Plota os pontos de dados brutos deste tiro
    ax.scatter(posicoes, tempos, label=f'Dados {nome_tiro}', marker='o', alpha=0.7, c=cor_dados)

    # --- 2. Análise dos Segmentos ---
    for nome_segmento, limites in segmentos_para_analise.items():
        dist_min = limites['dist_min']
        dist_max = limites['dist_max']
        cor_reta = limites['cor']
        
        mascara = (posicoes >= dist_min) & (posicoes <= dist_max)
        pos_segmento = posicoes[mascara]
        t_segmento = tempos[mascara]
        
        if len(pos_segmento) < 2:
            print(f"AVISO: Segmento '{nome_segmento}' do '{nome_tiro}' tem pontos insuficientes.")
            continue
            
        inclinacao, intercepto = np.polyfit(pos_segmento, t_segmento, 1)
        velocidade = abs(1 / inclinacao)
        
        print(f"  -> Segmento '{nome_segmento}': Velocidade = {velocidade:.2f} m/s")
        
        # Plota a reta de ajuste do segmento no gráfico principal
        ax.plot(pos_segmento, inclinacao * pos_segmento + intercepto, '-', color=cor_reta, lw=2.5, 
                label=f'Ajuste {nome_tiro} - {nome_segmento} ({velocidade:.0f} m/s)')

# --- 3. Configuração Final do Gráfico ---
ax.set_xlabel('Posição do Receptor (m)')
ax.set_ylabel('Tempo (s)')
ax.set_title('Análise Comparativa de Dromocronas')
ax.legend()
ax.grid(True)
ax.invert_yaxis()

nome_figura = 'analise_comparativa.png'
plt.savefig(nome_figura, dpi=300, bbox_inches='tight')
print(f"\nGráfico comparativo salvo como: {nome_figura}")

plt.show()
# Out:
# --- Iniciando Análise Comparativa de Tiros ---
#
# --- Analisando o 'n12': picks/nu=12.txt ---
# AVISO: Segmento 'Onda Direta' do 'n12' tem pontos insuficientes.
# AVISO: Segmento 'Refratada 1' do 'n12' tem pontos insuficientes.
#   -> Segmento 'Refratada 2': Velocidade = 1563.27 m/s
#
# --- Analisando o 'n13': picks/n13 ---
# AVISO: Segmento 'Onda Direta' do 'n13' tem pontos insuficientes.
#   -> Segmento 'Refratada 1': Velocidade = 1587.54 m/s
#   -> Segmento 'Refratada 2': Velocidade = 2007.08 m/s
#
# Gráfico comparativo salvo como: analise_comparativa.png
